# %% [markdown]
# # Colab pipeline launcher (ICS)
# This copy points to the canonical pipeline in `sub1quant/notebook/colab_hf_github_pipeline.ipynb`. Use it to run experiments from the ICS workspace in Colab.

# %%
print('Open the canonical pipeline notebook in sub1quant/notebook/colab_hf_github_pipeline.ipynb or copy its cells here.')
